# %% [markdown]
# We use solar flare [data from the RHESSI Mission](https://www.kaggle.com/datasets/khsamaha/solar-flares-rhessi/data) to predict the energy of a flare given observed characteristics

# %% [markdown]
# ### Preprocessing

# %%
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import keras_tuner
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
# Out:
# Using TensorFlow backend

# %%
df = pd.read_csv('./solarflares_rhessi.csv')
df
# Out:
#            flare  start.date start.time      peak       end  duration.s  \
# 0        2021213  2002-02-12   21:29:56  21:33:38  21:41:48         712
# 1        2021228  2002-02-12   21:44:08  21:45:06  21:48:56         288
# 2        2021332  2002-02-13   00:53:24  00:54:54  00:57:00         216
# 3        2021308  2002-02-13   04:22:52  04:23:50  04:26:56         244
# 4        2021310  2002-02-13   07:03:52  07:05:14  07:07:48         236
# ...          ...         ...        ...       ...       ...         ...
# 116138  18020903  2018-02-09   16:41:28  16:42:54  16:43:32         124
# 116139  18020904  2018-02-09   18:15:56  18:17:26  18:17:40         104
# 116140  18021001  2018-02-10   13:04:36  13:06:46  13:07:04         148
# 116141  18022601  2018-02-26   15:49:56  15:51:18  15:53:52         236
# 116142  18030301  2018-03-03   04:04:08  04:06:22  04:12:20         492
#
#         peak.c/s  total.counts energy.kev  x.pos.asec  y.pos.asec  radial  \
# 0            136      167304.0      12-25         592        -358     692
# 1              7        9504.0       6-12         604        -341     694
# 2             15       11448.0       6-12        -310         375     487
# 3             20       17400.0      12-25        -277         378     469
# 4            336      313392.0      25-50        -272         390     476
# ...          ...           ...        ...         ...         ...     ...
# 116138        18        2888.0       6-12        -345         -38     347
# 116139        16        1656.0       6-12        -268         -38     271
# 116140        15        2224.0       6-12        -115         -38     121
# 116141        16        3312.0       6-12         115         192     223
# 116142        42       15816.0       6-12         926         128     935
#
#         active.region.ar flag.1 flag.2 flag.3 flag.4 flag.5
# 0                      0     A1     P1    NaN    NaN    NaN
# 1                   9811     A1     P1     PE     Q1    NaN
# 2                   9825     A1     P1    NaN    NaN    NaN
# 3                   9822     A1     P1    NaN    NaN    NaN
# 4                   9825     A1     GS     P1     PE     Q2
# ...                  ...    ...    ...    ...    ...    ...
# 116138              2699     A0     DF     P1     PE     Q2
# 116139              2699     A0     DF     P1     PE     Q2
# 116140              2699     A0     DF     P1     PE     Q2
# 116141              2700     A0     DF     P1     PE     Q2
# 116142              2700     A0     P1     PE     Q1    NaN
#
# [116143 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['flare', 'start.date', 'start.time', 'peak', 'end', 'duration.s',
#        'peak.c/s', 'total.counts', 'energy.kev', 'x.pos.asec', 'y.pos.asec',
#        'radial', 'active.region.ar', 'flag.1', 'flag.2', 'flag.3', 'flag.4',
#        'flag.5'],
#       dtype='object')

# %%
df = df[[
    'duration.s',
    'peak.c/s',
    'total.counts',
    'energy.kev', 
    'x.pos.asec', 'y.pos.asec',
    'radial',
    'active.region.ar'
]]
NUM_FEATURES = len(df.columns) - 1

# %%
X = df.drop('energy.kev', axis=1).values

# %%
encoder = LabelEncoder()
encoder.fit(df['energy.kev'])
y = encoder.transform(df['energy.kev'])
y = to_categorical(y)
NUM_CLASSES = len(encoder.classes_)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Train and optimise the DNN

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Input(shape=(NUM_FEATURES,)))
    model.add(
        layers.Dense(
            units=hp.Int("units", min_value=32, max_value=512, step=32),
            activation=hp.Choice("activation", ["relu", "tanh"]),
        )
    )
    if hp.Boolean("dropout"):
        model.add(layers.Dropout(rate=0.25))
    model.add(layers.Dense(NUM_CLASSES, activation="softmax"))

    learning_rate = hp.Float("lr", min_value=1e-4, max_value=1e-2, sampling="log")
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

tuner = keras_tuner.Hyperband(
    hypermodel=build_model,
    objective="val_accuracy",
    factor=3,
    directory="tuning",
    project_name="solar_flare",
    max_epochs=10
)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    patience=10,
    restore_best_weights=True,
    start_from_epoch=5
)
tuner.search(X_train, y_train, epochs=50, validation_split=0.2, callbacks=[early_stopping])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""Optimal number of units in the first densely-connected layer:{best_hps.get('units')}\n
      Optimal learning rate for the optimizer: {best_hps.get('lr')}.""")
# Out:
# Reloading Tuner from tuning/solar_flare/tuner0.json
# Optimal number of units in the first densely-connected layer:320
#
#       Optimal learning rate for the optimizer: 0.0001809681061508976.

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopping])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 2323/2323 [==============================] - 2s 620us/step - loss: 2814.9614 - accuracy: 0.6324 - val_loss: 577.2590 - val_accuracy: 0.7670
# Epoch 2/100
# 2323/2323 [==============================] - 1s 547us/step - loss: 1965.8281 - accuracy: 0.6825 - val_loss: 1193.5383 - val_accuracy: 0.7253
# Epoch 3/100
# 2323/2323 [==============================] - 1s 590us/step - loss: 2001.3966 - accuracy: 0.7016 - val_loss: 1315.3257 - val_accuracy: 0.7769
# Epoch 4/100
# 2323/2323 [==============================] - 1s 635us/step - loss: 2026.0803 - accuracy: 0.7156 - val_loss: 4785.7046 - val_accuracy: 0.7357
# Epoch 5/100
# 2323/2323 [==============================] - 1s 607us/step - loss: 1655.1735 - accuracy: 0.7200 - val_loss: 921.6373 - val_accuracy: 0.6785
# Epoch 6/100
# 2323/2323 [==============================] - 1s 592us/step - loss: 1827.9529 - accuracy: 0.7267 - val_loss: 617.5685 - val_accuracy: 0.7818
# Epoch 7/100
# 2323/2323 [==============================] - 1s 605us/step - loss: 1918.6716 - accuracy: 0.7259 - val_loss: 6242.1455 - val_accuracy: 0.6454
# Epoch 8/100
# 2323/2323 [==============================] - 1s 575us/step - loss: 1920.1410 - accuracy: 0.7262 - val_loss: 1908.7881 - val_accuracy: 0.7220
# Epoch 9/100
# 2323/2323 [==============================] - 1s 583us/step - loss: 1786.7223 - accuracy: 0.7346 - val_loss: 602.0388 - val_accuracy: 0.7926
# Epoch 10/100
# 2323/2323 [==============================] - 1s 555us/step - loss: 1995.4945 - accuracy: 0.7310 - val_loss: 1494.6768 - val_accuracy: 0.8227
# Epoch 11/100
# 2323/2323 [==============================] - 1s 610us/step - loss: 1909.1648 - accuracy: 0.7341 - val_loss: 745.2632 - val_accuracy: 0.7422
# Epoch 12/100
# 2323/2323 [==============================] - 1s 581us/step - loss: 1551.1542 - accuracy: 0.7352 - val_loss: 540.2820 - val_accuracy: 0.5644
# Epoch 13/100
# 2323/2323 [==============================] - 1s 547us/step - loss: 1799.8322 - accuracy: 0.7353 - val_loss: 485.4885 - val_accuracy: 0.8034
# Epoch 14/100
# 2323/2323 [==============================] - 1s 576us/step - loss: 1982.5656 - accuracy: 0.7384 - val_loss: 1797.0652 - val_accuracy: 0.7890
# Epoch 15/100
# 2323/2323 [==============================] - 1s 595us/step - loss: 1804.0457 - accuracy: 0.7440 - val_loss: 982.7853 - val_accuracy: 0.5019
# Epoch 16/100
# 2323/2323 [==============================] - 1s 596us/step - loss: 1753.3491 - accuracy: 0.7354 - val_loss: 607.7075 - val_accuracy: 0.7870
# Epoch 17/100
# 2323/2323 [==============================] - 1s 597us/step - loss: 1555.9619 - accuracy: 0.7439 - val_loss: 607.6273 - val_accuracy: 0.4024
# Epoch 18/100
# 2323/2323 [==============================] - 1s 624us/step - loss: 1934.6163 - accuracy: 0.7268 - val_loss: 1280.3678 - val_accuracy: 0.4342
# Epoch 19/100
# 2323/2323 [==============================] - 1s 599us/step - loss: 1560.2186 - accuracy: 0.7419 - val_loss: 722.4462 - val_accuracy: 0.7868
# Epoch 20/100
# 2323/2323 [==============================] - 1s 639us/step - loss: 1856.6249 - accuracy: 0.7361 - val_loss: 3004.8521 - val_accuracy: 0.7556
# Epoch 21/100
# 2323/2323 [==============================] - 1s 597us/step - loss: 1789.0300 - accuracy: 0.7450 - val_loss: 1746.3042 - val_accuracy: 0.7565
# Epoch 22/100
# 2323/2323 [==============================] - 1s 624us/step - loss: 1665.2347 - accuracy: 0.7439 - val_loss: 1458.2802 - val_accuracy: 0.8121
# Epoch 23/100
# 2323/2323 [==============================] - 1s 588us/step - loss: 1730.3488 - accuracy: 0.7423 - val_loss: 1777.2246 - val_accuracy: 0.7555

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_accuracy}')
# Out:
# 726/726 [==============================] - 0s 386us/step - loss: 476.5717 - accuracy: 0.8096
# Test loss: 476.5716857910156
# Test accuracy: 0.8096345067024231
